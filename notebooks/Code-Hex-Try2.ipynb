# %%
# !pip install pyngrok
# !pip install flask_ngrok
# !pip install pillow
# !pip install torch
# !pip install salesforce-lavis
# !pip install langchain_openai

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/Code-Hex-V-0.02
# Out:
# /content/drive/MyDrive/Colab Notebooks/Code-Hex-V-0.02

# %%
ls -l
# Out:
# total 875751
# -rw------- 1 root root      3584 Sep  7 02:10 app.py
# -rw------- 1 root root 896748129 Sep  6 07:12 blip_caption.pkl
# -rw------- 1 root root      1824 Sep  6 07:12 blip_caption_vis_processor.pkl
# -rw------- 1 root root      6114 Sep  7 02:33 Code-Hex-Try2.ipynb
# drwx------ 2 root root      4096 Sep  7 00:58 static/
# drwx------ 2 root root      4096 Sep  7 00:57 templates/

# %%
# !python app.py
# Out:
# cuda
# 2024-09-07 03:02:43.503720: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-07 03:02:43.524798: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-07 03:02:43.530924: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-07 03:02:43.545716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
